# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Di chuyển vào thư mục gốc của Drive
# %cd /content/drive/MyDrive/


# Đi vào thư mục vừa tạo
# %cd TrafficSignProject
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/TrafficSignProject

# %%
# Tải file từ Hugging Face
# !wget -O vn_sign_detection.zip https://huggingface.co/datasets/Hoang42/VietNam_Traffic_sign_Augmentationed/resolve/main/vn_sign_detection.zip

# Giải nén ngay tại thư mục hiện tại
# !unzip vn_sign_detection.zip

# (Tùy chọn) Xóa file zip sau khi giải nén xong để đỡ tốn dung lượng Drive
# !rm vn_sign_detection.zip
# Out:
# --2026-05-17 09:01:55--  https://huggingface.co/datasets/Hoang42/VietNam_Traffic_sign_Augmentationed/resolve/main/vn_sign_detection.zip
# Resolving huggingface.co (huggingface.co)... 18.238.109.92, 18.238.109.52, 18.238.109.121, ...
# Connecting to huggingface.co (huggingface.co)|18.238.109.92|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
